# %% [markdown]
# # SpeechT5Processor

# %%
import torch
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
import soundfile as sf
import subprocess
import time
import os

# %%
# Cargar modelo y procesador
processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")
model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

# Usar embedding de locutor por defecto
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embedding = torch.tensor(embeddings_dataset[7306]["xvector"]).unsqueeze(0)

# Texto a sintetizar
text = "Hola, estoy probando sintesis de voz con SpeechT5."
inputs = processor(text=text, return_tensors="pt")

# Generar espectrograma
with torch.no_grad():
    speech = model.generate_speech(inputs["input_ids"], speaker_embedding, vocoder=vocoder)
# Out:
# tokenizer_config.json:   0%|          | 0.00/232 [00:00<?, ?B/s]
# spm_char.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/585M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/585M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/50.7M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# cmu-arctic-xvectors.py:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# 0000.parquet:   0%|          | 0.00/21.3M [00:00<?, ?B/s]
# ...

# %%
from datetime import datetime
now = datetime.now()
formatted_time = now.strftime("%Y%m%d%H%M%S")


# Guardar a archivo .wav
sf.write("./SpeechT5/voz_generada"+formatted_time+".wav", speech.numpy(), samplerate=16000)

# %% [markdown]
# # Coqui TTS

# %%
from TTS.api import TTS
from datetime import datetime

# %% [markdown]
# ## Español (España)

# %%
# Listar modelos disponibles (opcional)
# print(TTS.list_models())

# Elegir modelo en español
tts = TTS(model_name="tts_models/es/css10/vits")


now = datetime.now()
formatted_time = now.strftime("%Y%m%d%H%M%S")
# Texto en español

texto="Sí, mi experiencia con la Nintendo Switch 2, señoras y señores, ya les puedo contar como fue o qué sucedió esta semana. Hace como unos dos meses Nintendo me contacta y me dice, no, oye, vamos a anunciar o vamos a llevar a ciertas personas a probar la Nintendo Switch 2. Jalas o pandeas, me dijeron. Así decía el correo. Jalas o pandeas. La Sushi 2. Vale, madre, es que sí, dije hace mucho no voy a eventos, hace mucho no voy a probar ciertas cosas y dije, güey, sí me gustaría estar. Sí me gustaría estar. Recuerdo que el lanzamiento de la primera Nintendo Switch fue en Nueva York y yo sí le tuve un chingo de envidia a la gente que fue a probarla. Entonces pues ya fui, me tocó ir a Nueva York, gente. Me tocó ir a Nueva York. La neta para mí pues sí fue una toda una experiencia, un sueño cumplido, porque me pongo muy contento cada vez que una compañía me toma en cuenta para probar los primeros minutos de vida de una consola. ¿Cuál fue la primera? Sí, yo creo que la primera fue Xbox. La primera fue Xbox con su Xbox Series X que me lo mandaron y lo pude probar y pude transmitir en vivo y tuve mucha gente ahí en Facebook y se desenvivo transmitiendo mostrándola a la gente que era el nuevo y demás. Me hizo mucha ilusión y de hecho no se nota, pero en ese en vivo andaba yo con ganas de liberar y la chingada."

# tts.tts_to_file(text="Hola, esta es una prueba en español.", file_path="./SpeechT5/Coqui_salida_espanol"+formatted_time+".wav")
tts.tts_to_file(text=texto, file_path="./SpeechT5/Coqui_salida_espanol_fede"+formatted_time+".wav")

# %% [markdown]
# ### 1ra historia

# %%
text="Esta historia se llama: habitación sin salida." \
"No recuerdo cómo llegué a este lugar. Solo sé que, al abrir los ojos, estaba en una habitación blanca, sin ventanas, sin puertas." \
"No sentía hambre, ni frío. Solo esa incomodidad de saber que algo estaba mal." \
"Caminaba de un lado a otro, buscando alguna grieta, alguna marca en las paredes lisas. Nada." \
"El techo era tan alto que se perdía en una bruma pálida." \
"El suelo, blando como si pisara sobre algo que respiraba lentamente." \
"Al principio pensé que era un sueño. Me pellizqué, grité, rasgué mis uñas contra las paredes." \
"Todo era real." \
"Pasaron horas. O días. El tiempo no existía en ese lugar." \
"Solo yo y mis pensamientos, repitiéndose como un eco interminable." \
"A veces, en las paredes, aparecían breves destellos: imágenes que desaparecían si parpadeaba." \
"Una calle conocida." \
"Un rostro querido." \
"Mi propia habitación, vacía." \
"Intenté hablar, gritar, suplicar." \
"Nadie respondía." \
"Hasta que un día, en el centro de la habitación, apareció una puerta diminuta, apenas lo suficientemente grande para meter la mano." \
"Me acerqué, desesperado." \
"Escuché voces al otro lado. Voces que me llamaban por mi nombre." \
"Metí la mano... y sentí dedos aferrándose a la mía." \
"Pero no tiraban de mí para sacarme." \
"Tiraban para arrastrarme más adentro." \
"Intenté soltarme, pero era tarde." \
"Fui absorbido por esa grieta diminuta, cayendo hacia un vacío de susurros y risas apagadas." \
"Ahora no estoy seguro de dónde estoy." \
"A veces veo lugares familiares, gente que parece no verme." \
"A veces sueño con estar de nuevo en aquella habitación blanca." \
"O quizás... nunca salí de allí."

now = datetime.now()
formatted_time = now.strftime("%Y%m%d%H%M%S")
tts.tts_to_file(text=text, file_path="./SpeechT5/Coqui_HabitaciónSinSalida"+formatted_time+".wav", speed=10)
# Out:
#  > Text splitted to sentences.
# ...

# %% [markdown]
# ### Removiendo silencios FORMA 1

# %%
tts = TTS(model_name="tts_models/es/css10/vits")
# Out:
#  > tts_models/es/css10/vits is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > initialization of speaker-embedding layers.
#  > initialization of language-embedding layers.

# %%
prefijo="HabitaciónSinSalida"

frases=["Esta historia se llama: Habitación sin salida.",
"No recuerdo cómo llegué a este lugar.",
"Solo sé que, al abrir los ojos, estaba en una habitación blanca, sin ventanas, sin puertas.",
"No sentía hambre, ni frío.",
"Solo esa incomodidad de saber que algo estaba mal.",
"Caminaba de un lado a otro, buscando alguna grieta, alguna marca en las paredes lisas.",
"Nada.",
"El techo era tan alto que se perdía en una bruma pálida.",
"El suelo, blando como si pisara sobre algo que respiraba lentamente.",
"Al principio pensé que era un sueño.",
"Me pellizqué, grité, rasgué mis uñas contra las paredes.",
"Todo era real.",
"Pasaron horas o días.",
"El tiempo no existía en ese lugar.",
"Solo yo y mis pensamientos, repitiéndose como un eco interminable.",
"A veces, en las paredes, aparecían breves destellos: imágenes que desaparecían si parpadeaba.",
"Una calle conocida.",
"Un rostro querido.",
"Mi propia habitación, vacía.",
"Intenté hablar, gritar, suplicar.",
"Nadie respondía.",
"Hasta que un día, en el centro de la habitación, apareció una puerta diminuta, apenas lo suficientemente grande para meter la mano.",
"Me acerqué, desesperado.",
"Escuché voces al otro lado.",
"Voces que me llamaban por mi nombre.",
"Metí la mano... y sentí dedos aferrándose a la mía.",
"Pero no tiraban de mí para sacarme.",
"Tiraban para arrastrarme más adentro.",
"Intenté soltarme, pero era tarde.",
"Fui absorbido por esa grieta diminuta, cayendo hacia un vacío de susurros y risas apagadas.",
"Ahora no estoy seguro de dónde estoy.",
"A veces veo lugares familiares, gente que parece no verme.",
"A veces sueño con estar de nuevo en aquella habitación blanca.",
"O quizás... nunca salí de allí."]

# %%
prefijo="BancodelParque"

frases=[
  "Esta historia se llama: El banco del parque.",
  "Siempre me ha gustado sentarme en el mismo banco del parque, justo frente al lago.",
  "Lo hago cada tarde, desde que tengo memoria.",
  "Observo a la gente pasar: madres con cochecitos, ancianos caminando lento, niños persiguiendo palomas.",
  "Nadie me presta demasiada atención, y eso me gusta.",
  "Una vez, un niño se acercó y me preguntó si estaba esperando a alguien.",
  "Le respondí que sí, pero que aún no llegaba.",
  "No sé por qué dije eso.",
  "La verdad es que no estoy esperando a nadie.",
  "O eso creía.",
  "Hace unos días, una mujer se sentó a mi lado.",
  "Llevaba flores en las manos y los ojos tristes.",
  "No me miró, pero empezó a hablar en voz baja.",
  "Me contó que solía venir aquí con su esposo, que se sentaban justo en este banco.",
  "Dijo que él murió hace un año... el mismo día que ella encontró una nota suya diciendo que iría al parque una última vez.",
  "Yo no dije nada.",
  "Solo la escuché mientras algo en mi pecho dolía sin razón.",
  "Cuando se levantó, dejó las flores sobre el banco.",
  "Al irse, se detuvo un segundo y murmuró: 'Ojalá supieras que aún vengo por ti.'",
  "Desde entonces, el banco huele a flores frescas, aunque nadie más las ve.",
  "Y cada vez que la veo acercarse, siento algo que casi recuerdo.",
  "Creo... que yo era él.",
  "Pero no estoy seguro.",
  "Solo sé que no puedo irme de este lugar.",
  "Y que ahora sí, la estoy esperando."
]

# %%
prefijo="HuespedSilencioso"

frases=[
  "Esta historia se llama: El huésped silencioso.",
  "Cada invierno, la casona de los Echeverría permanecía cerrada, envuelta en nieve y silencio.",
  "Pero una vez al año, sin falta, alguien dejaba una vela encendida en la ventana del cuarto del ático.",
  "Los vecinos lo notaban, aunque juraban que nadie había entrado ni salido.",
  "Algunos pensaban que era un sistema automático, otros preferían no hablar del tema.",
  "Cuarenta años atrás, un niño había desaparecido en esa misma casa durante una tormenta.",
  "Su madre lo había dejado solo apenas unos minutos, bajó por leña y, al volver, el niño ya no estaba.",
  "Buscaron durante semanas, pero nunca hallaron rastro alguno.",
  "Desde entonces, la familia abandonó la propiedad, aunque la mantuvieron en pie.",
  "Con el tiempo, la historia se volvió leyenda.",
  "Este año, sin embargo, un curioso decidió acercarse durante una nevada especialmente densa.",
  "Saltó la verja oxidada, subió la colina, y forzó la cerradura de la puerta trasera.",
  "La casa estaba intacta: muebles cubiertos, aire denso, olor a madera húmeda.",
  "Subió al ático siguiendo la débil luz de la vela.",
  "Allí encontró una pequeña cama hecha con pulcritud, una manta doblada y un cuaderno abierto.",
  "Las páginas estaban llenas de dibujos infantiles: casas, árboles, una madre sonriente... y él mismo, observando por la ventana.",
  "Sintió un escalofrío y giró hacia la entrada.",
  "En la pared, escrito con crayón, se leía: 'Gracias por volver este año. Siempre sé cuándo vendrás.'",
  "El hombre bajó corriendo, sin mirar atrás.",
  "Al llegar al pueblo, intentó contar lo que había visto, pero nadie lo escuchó.",
  "No porque no quisieran... sino porque no lo veían.",
  "Murió en esa misma colina hacía ya muchos años, en la misma nevada en que decidió romper el candado por primera vez."
]

# %%
prefijo="CaminantesNocturnos"

frases=[
	"Yo soy El Carretero y esta historia se llama: Los que caminan de noche.",
  "En el pueblo de San Mirel, todos sabían que no se debía salir después del último canto del gallo.",
  "Era una regla no escrita, pero nadie la rompía.",
  "No había patrullas, ni amenazas, solo una certeza silenciosa compartida por todos.",
  "Al caer la noche, las luces se apagaban, las puertas se cerraban y las cortinas se corrían sin excepción.",
  "Una familia nueva llegó al pueblo a mediados de otoño, ajenos a la costumbre.",
  "Eran citadinos, escépticos, sonrientes ante la superstición.",
  "Esa misma noche, decidieron dar un paseo nocturno.",
  "La hija menor, Emilia, corrió entre los árboles, riendo, hasta que su risa se cortó de golpe.",
  "La madre gritó su nombre durante horas, pero solo obtuvo silencio como respuesta.",
  "Cuando salió el sol, la niña apareció sentada en el porche, descalza, cubierta de hojas secas.",
  "No recordaba nada, o al menos eso decía.",
  "Pero desde entonces, algo cambió.",
  "No comía, no dormía, no parpadeaba.",
  "Y a medianoche exacta, se paraba frente a la ventana, completamente quieta.",
  "Los vecinos no se sorprendieron.",
  "Solo dijeron: 'A veces, no se las llevan. A veces, dejan algo a cambio.'",
  "Desde entonces, los padres cierran la casa con llave, aunque saben que no sirve de nada.",
  "Porque cada noche, cuando todos duermen, Emilia sale por la puerta... sin abrirla.",
  "Camina hacia el bosque, donde otros niños la esperan, igual de quietos, igual de vacíos.",
  "Y todos juntos... caminan de noche."
  
]

# %%
prefijo="ElRetrato"

frases=[
	"Yo soy El Carretero y esta historia se llama: El retrato que no envejecía.",
	"En la galería del museo regional, había un cuadro colgado en una sala poco visitada.",
	"Era el retrato de un joven vestido con ropas del siglo XIX, de mirada intensa y gesto sereno.",
	"La pintura no tenía autor conocido, ni firma visible.",
	"Solo una pequeña placa que decía: 'Donado en 1891'.",
	"Durante décadas, el retrato permaneció allí, sin deteriorarse, sin polvo, como si el tiempo no lo tocara.",
	"Pero lo más extraño era que los trabajadores del museo afirmaban que los ojos del joven seguían con la mirada a quien lo observaba.",
	"Algunos visitantes decían que el rostro cambiaba sutilmente según la hora del día.",
	"Un día, una restauradora joven fue asignada a examinar la pintura de cerca.",
	"Notó algo peculiar: la superficie no era de óleo, ni tela, ni madera.",
	"Era como piel… tensa, firme, ligeramente tibia.",
	"Al raspar con delicadeza una esquina oculta del lienzo, encontró algo debajo.",
	"Una capa delgada, translúcida, y bajo ella… un ojo humano que se movió.",
	"Gritó, retrocedió, pero al volverse hacia la puerta, la sala ya no era la misma.",
	"La galería había desaparecido; ahora había columnas antiguas, cortinas pesadas, y una chimenea encendida.",
	"Frente a ella, sentado en un sillón, estaba el joven del retrato, idéntico, inmutable.",
	"Él le sonrió y dijo: 'Siempre necesitaremos a alguien que cuide el marco… desde dentro.'",
	"El museo abrió al día siguiente como si nada.",
	"Nadie preguntó por la restauradora.",
	"Pero si uno mira con atención el retrato hoy, hay algo nuevo en el fondo: una figura borrosa, reflejada en un espejo.",
	"Parece una mujer gritando."
]

# %%
prefijo="CurvaAhorcado"

frases=[
  "Dicen que recorro los caminos más viejos... Yo soy El Carretero y esta historia se llama: La curva del ahorcado.",
  "En un tramo olvidado de la carretera vieja, hay una curva tan cerrada que ningún mapa la dibuja igual dos veces.",
  "Los camioneros la evitan, los ge pe eses se bloquean, y los postes de luz nunca duran más de una semana.",
  "Una noche de tormenta, un joven conductor tomó el desvío equivocado y terminó en ese tramo.",
  "No debía estar ahí, pero no lo sabía todavía. ",
  "A mitad de la curva, vio una figura colgando de un árbol torcido al borde del asfalto.",
  "Pensó que era una ilusión, la lluvia, el cansancio.",
  "Pero cuando volvió a mirar, el cuerpo seguía ahí, girando lentamente, los pies descalzos rozando el aire.",
  "Frenó en seco, salió del coche, y la figura había desaparecido.",
  "Al volver a entrar, encontró el asiento del copiloto mojado, como si alguien se hubiera sentado justo allí.",
  "Siguió manejando, temblando, hasta que la misma curva apareció de nuevo frente a él.",
  "Dio la vuelta, y otra vez la curva.",
  "Una y otra vez, como si el camino se enroscara sobre sí mismo.",
  "Horas más tarde, cuando lo encontraron, estaba parado en medio del asfalto, murmurando sin parar.",
  "Decía: 'Yo no quería ver. Yo no quería ver.'",
  "Desde entonces, cuando alguien desaparece por allí, los árboles crujen aunque no haya viento.",
  "Y a veces, los que pasan por la curva juran ver a alguien al borde del camino con una cuerda en la mano.",
  "Esperando.",
  "Yo no paso por ahí desde entonces.",
  "Pero si vas... y sientes que algo se sube al asiento del copiloto... no mires.",
  "Porque si lo haces, nunca lograrás salir de la curva."
]

# %%
prefijo="PuenteOlvida"

frases=[
  "Me llaman El Carretero de los caminos viejos, y esta historia se llama: El puente que no olvida.",
  "Hace mucho, cuando los pueblos eran solo polvo, bueyes y campanas, existía un puente de piedra sobre un río que ya no corre.",
  "Era un puente corto, sin barandas, escondido entre sauces que susurraban secretos si el viento los tocaba de noche.",
  "Los lugareños evitaban cruzarlo al anochecer, no por miedo... sino por respeto.",
  "Decían que, cada cierto tiempo, alguien debía entregarse al río que ya no existe.",
  "Nadie lo decía en voz alta, pero todos sabían cuándo era el turno de uno.",
  "La historia comienza con Clara, una joven que nació en un año sin lluvias, cuando los perros no ladraban de noche.",
  "Era distinta, decían; hablaba sola, miraba al cielo y reía en los entierros.",
  "Un día, sin razón aparente, Clara fue vista caminando hacia el puente justo cuando el sol caía detrás de los cerros.",
  "La siguieron, pero al llegar, no encontraron a nadie, solo un ramo de flores secas y una cinta roja flotando donde el agua solía correr.",
  "Desde entonces, una figura comenzó a aparecer al borde del puente, cada vez que el reloj marcaba la misma hora.",
  "No caminaba, no hablaba, solo miraba hacia donde solía estar el río.",
  "Los viajeros que venían con brújula o con ge pe ese decían que sus aparatos enloquecían cerca del lugar.",
  "Los mapas mostraban el puente, pero no los caminos que llevaban a él.",
  "Una pareja de forasteros intentó pasar por ahí una noche; solo ella volvió, con el cabello blanco como la sal.",
  "No habló nunca más.",
  "Muchos años después, un niño dibujó el puente en clase sin haberlo visto jamás.",
  "Cuando la maestra le preguntó cómo lo conocía, respondió: 'Porque la señora de los ojos tristes me lo enseñó en un sueño.'",
  "Aún hoy, cuando viajo cerca de esa región, evito tomar el desvío de tierra con el cartel torcido.",
  "Dicen que, si cruzas ese puente cuando nadie más lo ve, puedes escuchar el río... aunque esté seco.",
  "Pero también dicen que, si lo escuchas, es porque alguien está esperando del otro lado."
]

# %%
prefijo="RuedasHueso"

frases=[
  "Soy El Carretero, el que conoce los atajos que ya no aparecen en los mapas, y esta historia se llama: La carreta con ruedas de hueso.",
  "Mucho antes de que existieran las fronteras, antes de los relojes y los ge pe eses, hubo un camino que no llevaba a ningún lugar visible.",
  "Dicen que solo aparece en noches sin luna, cuando la neblina baja como si buscara algo entre los vivos.",
  "En ese camino —empedrado con cráneos, dicen algunos— se escucha a lo lejos el rechinar de una carreta.",
  "Pero no es cualquier carreta: sus ruedas giran aunque no toquen el suelo, y su conductor no tiene rostro.",
  "Quienes lo han visto cuentan que su voz no suena afuera, sino dentro del pecho.",
  "Solo hace una pregunta: '¿A dónde quieres ir que no puedas volver?'",
  "Una vez, un erudito del norte —viejo, ciego, cansado de estar vivo— dijo que esperaría esa carreta para que lo llevara a ver a su esposa muerta.",
  "La gente se reía, pero la noche que murió, los perros huyeron sin razón y el viento dejó de moverse.",
  "La mañana siguiente, sus huellas llevaban al bosque, pero ninguna regresaba.",
  "Otra vez, un ladrón perseguido por la ley suplicó por un escape.",
  "Desapareció tras una tormenta, y al poco tiempo, encontraron una carreta abandonada hecha de huesos pulidos y sogas trenzadas con cabello humano.",
  "Los sabios del lugar advirtieron que no es una carreta para llevarte a donde quieres, sino a donde mereces.",
  "Nadie la ha visto dos veces y vivido para contarlo.",
  "Pero hay quienes aseguran que, si te detienes en el lugar exacto donde la niebla toca el suelo y silbas una melodía olvidada, puedes invocarla.",
  "Eso sí: debes subir sin dudar, sin mirar atrás, sin preguntar quién más va contigo.",
  "Porque se dice que los otros pasajeros... no siempre están muertos.",
  "Solo extraviados.",
  "Y algunos, incluso, aún creen que pueden bajarse."
]

# %%
prefijo="NinoDeLaVentana"

frases=[
  "Yo soy El Carretero, y esta historia me la contó un médico en una noche de lluvia. Se llama: El niño en la ventana.",
  "Decía que hace años, cuando aún hacía visitas a domicilio, lo llamaron a una casa aislada en un pueblo de paso.",
  "La madre estaba pálida, casi sin voz. Dijo que su hijo no comía, no dormía, y no dejaba de mirar por la ventana.",
  "El médico subió al cuarto y encontró al niño sentado, inmóvil, con la vista clavada en el bosque.",
  "Le habló, le preguntó su nombre, su edad, pero el niño solo respondió una vez: 'Él viene cada noche, pero solo yo puedo verlo.'",
  "El médico pensó en delirios febriles, esquizofrenia infantil... anotó recetas y dio instrucciones.",
  "Pero antes de irse, echó un vistazo a la ventana por curiosidad.",
  "No vio nada, solo árboles quietos bajo la lluvia.",
  "Volvió a la casa una semana después, pero estaba vacía.",
  "Las cortinas colgaban rasgadas, la mesa cubierta de polvo, y en el piso encontró un dibujo hecho a lápiz.",
  "Era una figura alta, sin rostro, de brazos larguísimos, de pie junto al niño que lo había dibujado.",
  "Días después, preguntó en el pueblo por la familia.",
  "Nadie los conocía.",
  "Mostró el dibujo en la tienda, en la escuela, incluso en la comisaría.",
  "Un anciano lo tomó con manos temblorosas y dijo: 'Este niño también vino a verme cuando era pequeño. Me contó lo mismo.'",
  "Y luego añadió, en voz baja: 'Él elige a uno cada generación.'",
  "El médico, ya retirado, dice que desde entonces sueña con la ventana del niño.",
  "No sabe dónde está, pero cada noche, en su sueño, está más cerca.",
  "Yo no sé si lo que contó es verdad.",
  "Solo sé que, desde esa noche, cuando paso frente a ciertas casas olvidadas… no miro hacia las ventanas."
]

# %%
prefijo="AndenNumeroNueve"

frases=[
  "Yo soy El Carretero, y esta historia me la contó un barrendero en la estación de tren. Se llama: El andén número nueve.",
  "Decía que en la vieja terminal de San Obelio, el andén número nueve estaba cerrado desde hacía décadas.",
  "La estructura seguía allí: hierro oxidado, bancos de madera astillada, relojes detenidos en las tres treintaytres.",
  "Pero de vez en cuando, se oían pasos por la noche.",
  "El barrendero, que limpiaba los pasillos cuando todos dormían, juraba que cada viernes escuchaba una locomotora lejana que nadie más oía.",
  "Al principio creyó que era el eco de su mente cansada.",
  "Hasta que una madrugada, vio una luz tenue aproximarse por las vías oxidadas.",
  "No había trenes funcionando desde hacía años, pero ahí estaba: una máquina negra, antigua, envuelta en vapor que no quemaba.",
  "Las puertas se abrieron, y del interior bajó una mujer con un sombrero verde y un vestido de otra época.",
  "Lo miró directo a los ojos y le dijo: '¿Ha pasado mucho tiempo? No sentí el viaje.'",
  "Y sin esperar respuesta, caminó por la estación y desapareció entre las sombras.",
  "Desde entonces, él regresaba cada viernes, mismo lugar, misma hora.",
  "Y cada semana, bajaba alguien más del tren: un niño con uniforme escolar, un soldado con la mirada perdida, una anciana cargando flores secas.",
  "Todos preguntaban lo mismo: '¿Ha pasado mucho tiempo?'",
  "Y todos se desvanecían tras caminar unos pasos.",
  "El barrendero no volvió a hablar mucho después de eso.",
  "Solo decía que el andén número nueve no llevaba a ningún lugar, sino que traía de vuelta lo que el mundo había olvidado.",
  "Una noche, simplemente no volvió.",
  "Pero si uno camina por la estación abandonada, a veces puede oler carbón, oír silbatos antiguos, y ver huellas recientes donde no camina nadie.",
  "A mí me contaron esa historia una sola vez, pero cada vez que paso por un andén vacío, bajo la cabeza.",
  "No por miedo, sino por respeto.",
  "Porque a veces, lo que regresa… no quiere irse otra vez."
]

# %%
prefijo="SombraEnElAnden"

frases=[
  "Dicen que soy El Carretero, el que escucha historias en cada rincón del camino. Esta se llama: La sombra en el andén.",
  "Una noche, en la estación central de una ciudad que nunca duerme, un vigilante llamado Mateo realizaba su ronda habitual.",
  "Eran cerca de las tres de la mañana cuando notó que el tren de la línea siete, que no opera a esa hora, estaba detenido en el andén.",
  "Extrañado, se acercó para investigar, pero no encontró a nadie a bordo.",
  "Las luces del tren parpadeaban, y un leve murmullo parecía emanar de su interior.",
  "Mateo subió al vagón y caminó por el pasillo vacío, sintiendo una creciente inquietud.",
  "Al llegar al último vagón, vio una figura oscura sentada al final, mirando por la ventana.",
  "Le pidió que descendiera, pero la figura no respondió.",
  "Al acercarse, la figura se desvaneció ante sus ojos, dejando solo un asiento vacío.",
  "Sobresaltado, Mateo bajó del tren, pero al volver la vista, el tren ya no estaba.",
  "Solo quedaba el andén vacío y el eco de su propia respiración.",
  "Desde entonces, cada noche a la misma hora, el tren aparece y desaparece sin explicación.",
  "Algunos dicen que es el alma de un conductor que falleció en un accidente años atrás, buscando completar su ruta.",
  "Otros creen que es una advertencia para quienes desafían las reglas del tiempo y el espacio.",
  "Mateo nunca volvió a trabajar en la estación, y su cabello encaneció prematuramente.",
  "Yo no sé si lo que me contó es verdad.",
  "Solo sé que, desde entonces, cuando paso por estaciones solitarias en la madrugada, evito mirar hacia los andenes vacíos."
]

# %%
prefijo="CasaRespira"

frases=[
  "Me llaman El Carretero. Esta historia se llama: La casa que respiraba.",
  "Una mujer anciana vivía sola en una casa de campo.",
  "La casa estaba construida con madera vieja.",
  "Cada noche se oía crujir como si algo dentro se moviera.",
  "Ella decía que era solo el viento.",
  "Pero los vecinos aseguraban haberla oído hablar con alguien.",
  "Una noche de luna nueva la mujer fue a dormir como siempre.",
  "Cerró todas las puertas.",
  "Apagó las luces.",
  "Pero al acostarse escuchó un suspiro detrás de la pared.",
  "No un crujido. Un suspiro.",
  "Como de algo que duerme profundo.",
  "Se quedó inmóvil.",
  "La respiración continuaba. Lenta. Constante.",
  "Fue al día siguiente que descubrió marcas en el suelo.",
  "Huellas pequeñas. Como de manos. Pero con más dedos.",
  "Pensó en ratones.",
  "Hasta que vio una marca más grande bajo la cama.",
  "Parecía una cara. Dibujada por el polvo. Sonriendo.",
  "Desde entonces cada noche la casa exhalaba antes de dormir.",
  "Y cada mañana una silla estaba movida.",
  "Un mueble cambiado de sitio.",
  "Pero no había nadie más con ella.",
  "Cuando murió nadie reclamó la casa.",
  "Sigue vacía.",
  "Aunque dicen que si pasas cerca en la madrugada puedes oírla respirar.",
  "Yo no sé si esa casa está viva o solo está esperando.",
  "Pero no me detengo cuando paso por ahí.",
  "Y si vas... no lleves nada que no quieras que se quede adentro."
]

# %%
prefijo="FaroOlasNegras"

frases=[
  "Yo soy El Carretero, y esta historia me la contó un marinero. Se llama: El faro de las olas negras.",
  "En una isla lejana, un faro se erige sobre un acantilado rocoso.",
  "El faro nunca tuvo luz, pero siempre estuvo encendido.",
  "Los barcos lo veían desde lejos y lo evitaban.",
  "Los pescadores decían que las olas alrededor eran más oscuras cerca de él.",
  "Nadie se atrevía a acercarse, pero un hombre decidió que iría.",
  "Era un joven que creía que los mitos eran solo historias.",
  "Cuando llegó, la puerta del faro estaba abierta.",
  "Dentro, todo estaba en silencio.",
  "Un eco distante llenaba el aire, como si alguien estuviera susurrando entre las paredes.",
  "Subió hasta la cima, pero al llegar encontró que no había lámpara.",
  "Solo había una silla, con una cuerda atada al respaldo.",
  "Al mirar hacia el mar, vio las olas negras formándose como figuras humanas.",
  "El viento comenzó a soplar con fuerza.",
  "Las olas chocaron contra las rocas, pero no hicieron ruido.",
  "Eran perfectas, como si el mar tuviera conciencia.",
  "De repente, el joven vio una sombra a lo lejos.",
  "Una figura flotaba sobre el agua.",
  "No caminaba. Flotaba.",
  "Se acercó lentamente hacia el faro.",
  "Cuando llegó al pie del acantilado, la figura levantó la mano.",
  "El joven intentó gritar, pero no pudo.",
  "Alguien estaba sosteniéndole la garganta.",
  "Desde ese día, nadie volvió a ver al joven.",
  "Los barcos que pasaban veían el faro, pero las olas negras nunca desaparecieron.",
  "Y cuando alguien preguntaba por el joven, los pescadores solo decían: 'El mar ya lo tiene.'",
  "Yo no sé si el mar realmente lo reclamó.",
  "Solo sé que desde entonces, cuando paso cerca del mar en la noche, nunca miro al horizonte."
]

# %% [markdown]
# #### Mejorando

# %%
prefijo="RelojNoMarcaHora"

frases=[
  "Soy El Carretero, y esta historia me la contó un anciano que conocí en un puerto olvidado. Se llama: El reloj que no marca la hora.",
  "Era un pueblo costero, donde el mar siempre parecía estar más cerca de lo que debería.",
  "En el centro del pueblo, había una pequeña tienda de antigüedades.",
  "La tienda estaba llena de relojes antiguos, algunos de pie, otros de pared, y unos más pequeños, de bolsillo.",
  "Uno de los relojes era especialmente peculiar.",
  "Era un reloj de torre, con un diseño tallado en madera oscura.",
  "El reloj nunca marcaba la hora, pero siempre hacía tic-tac, como si estuviera vivo.",
  "Los habitantes del pueblo decían que quien intentaba darle cuerda desaparecía.",
  "Nadie lo tocaba, solo lo observaban desde lejos.",
  "Un día, un joven curioso entró a la tienda y pidió que le mostraran el reloj.",
  "El anciano dueño de la tienda se lo permitió, aunque con una advertencia: 'Nunca pongas tus manos sobre él, o serás parte de su historia.'",
  "El joven ignoró la advertencia y, al tocar el reloj, vio que las agujas comenzaron a moverse de manera errática.",
  "Pero en lugar de marcar una hora, el reloj parecía girar hacia atrás.",
  "De repente, una sombra emergió del reloj, como si algo estuviera siendo liberado de su interior.",
  "La sombra envolvió al joven, y él desapareció en un parpadeo.",
  "Los habitantes del pueblo nunca volvieron a ver al joven.",
  "Lo único que quedó fue el sonido del reloj, que ahora sonaba a la mitad del día y a la mitad de la noche.",
  "Y cada vez que alguien pasaba por la tienda, podía ver que las agujas del reloj marcaban la misma hora.",
  "El anciano me contó esta historia sentado junto al fuego, esa noche en la que las olas del mar parecían cantar.",
  "Cuando le pregunté qué había pasado con el joven, él solo sonrió y dijo: 'A veces, el tiempo no es lo que creemos.'",
  "Yo nunca he tocado ese reloj.",
  "Pero si alguna vez vas a ese pueblo, no mires al reloj, ni siquiera de reojo."
]

# %%
prefijo="VagonSellado"

frases=[
  "Me llaman El Carretero, y esta historia me la contó una mujer en una vieja estación de trenes abandonada. Se llama: El vagón sellado.",
  "La mujer era delgada, de voz suave, con un abrigo que parecía demasiado grande para su cuerpo.",
  "Me ofreció un cigarro y me dijo que hacía muchos años trabajaba en los trenes de carga.",
  "Una noche, mientras revisaban los vagones antes de partir, notaron que uno estaba completamente cerrado.",
  "Nadie lo recordaba en la lista de despacho.",
  "No tenía número, ni sello de aduana, ni marcas de procedencia.",
  "Alguien intentó abrirlo pero la puerta estaba sellada desde dentro.",
  "No había forma de forzarla.",
  "El jefe de estación, irritado, ordenó que lo dejaran en un apartadero hasta el día siguiente.",
  "Esa noche comenzó una lluvia que duró tres días.",
  "Y al cuarto día, cuando el sol volvió a salir, el vagón seguía allí.",
  "Pero ahora tenía marcas en el exterior.",
  "Como si desde adentro hubieran arañado la madera con desesperación.",
  "Nadie quería acercarse.",
  "Los perros del lugar no paraban de aullar.",
  "Alguien dijo que era mejor quemarlo.",
  "El jefe de estación se negó. Dijo que eso sería destruir propiedad del Estado.",
  "Esa noche desapareció sin dejar rastro.",
  "Y al día siguiente el vagón también había desaparecido.",
  "No quedaban marcas en los rieles.",
  "No había señales de grúa ni de traslado.",
  "Solo un espacio vacío y un olor a óxido viejo.",
  "La mujer me dijo que desde entonces ve ese vagón en sueños.",
  "Siempre está cerrado.",
  "Siempre oye algo adentro.",
  "Y siempre despierta con marcas en los brazos.",
  "Yo no sé qué fue lo que encerraron ahí.",
  "Solo sé que algunas cosas no se abren porque no deben.",
  "Y que hay trenes que no llevan carga sino castigos."
]

# %%
prefijo="LosQueCuelganDelCielo"

frases=[
  "Yo soy El Carretero, y esta historia me la contó un hombre con manos temblorosas, en algún lugar donde el viento parecía hablar. Se llama: Los que cuelgan del cielo.",
  "Él no me dio su nombre, solo dijo que había trabajado en una torre de vigilancia en lo alto de una montaña.",
  "La torre estaba sola, lejos de cualquier pueblo, rodeada de árboles que crujían incluso sin viento.",
  "Su trabajo era sencillo, subir cada mañana, vigilar, anotar, bajar cada tarde.",
  "Durante años no vio nada fuera de lo común.",
  "Hasta que una noche, en una tormenta, algo se colgó del cielo.",
  "No bajó del cielo, se colgó.",
  "Como si algo invisible lo sujetara desde arriba, sin ruido, sin forma clara.",
  "Parecía un cuerpo, suspendido en el aire, girando lentamente.",
  "El hombre creyó que era un espejismo del cansancio.",
  "Pero al día siguiente, había dos.",
  "Y al tercero, cuatro.",
  "Todos colgados del cielo, flotando en silencio sobre los árboles.",
  "No se movían con el viento.",
  "No proyectaban sombra.",
  "Al cuarto día intentó bajar de la torre.",
  "Pero no encontró el camino.",
  "El bosque había cambiado.",
  "Los árboles estaban más juntos, más altos, más oscuros.",
  "El cielo se volvía más bajo.",
  "Las figuras seguían colgadas, observando.",
  "Dijo que estuvo atrapado allá arriba durante lo que sintió como semanas.",
  "Hasta que una noche despertó de golpe, acostado en medio del camino de tierra.",
  "La torre ya no estaba.",
  "Solo el cielo, claro, sin nada suspendido.",
  "Me miró fijo y dijo que nunca volvió a mirar hacia arriba.",
  "Yo no le pregunté más.",
  "Solo pensé que hay cosas que uno solo debe mirar una vez en la vida.",
  "Y que quizás el cielo no está tan vacío como creemos."
]

# %%
prefijo="PozoSeco"

frases=[
  "Yo soy El Carretero, y esta historia me la contó una muchacha con voz temblorosa, en algún lugar donde los caminos parecían olvidarse de sí mismos. Se llama: La voz del pozo seco.",
  "La muchacha había vivido sola durante muchos años en una casa vieja, rodeada por tierra agrietada y árboles torcidos.",
  "No tenía familia, solo un pozo seco en el patio que nunca había dado agua, pero que siempre estaba allí, como si vigilara.",
  "Cada mañana barría las hojas alrededor, cada noche cerraba bien la tapa de madera con una piedra encima.",
  "Nunca lo usó, pero tampoco se atrevía a taparlo por completo.",
  "Dijo que una vez, cuando era niña, escuchó su nombre saliendo desde dentro.",
  "Pensó que era el viento, o algún animal atrapado.",
  "Pero la voz no gritaba, ni pedía ayuda, solo susurraba su nombre, una y otra vez.",
  "Con los años, aprendió a ignorarlo.",
  "Hasta que una noche, mientras dormía, oyó pasos cerca de su cama.",
  "Despertó, no había nadie, pero la piedra que cubría el pozo ya no estaba en su sitio.",
  "Bajó con una linterna, temblando, y vio la tapa abierta, con las hojas esparcidas como por manos pequeñas.",
  "Se asomó, y el pozo no estaba seco.",
  "Pero no había agua, solo oscuridad que parecía respirar.",
  "Dejó caer una cuerda con una piedra, pero nunca oyó el fondo.",
  "Solo la voz regresó, más clara, más cercana.",
  "Le pedía bajar.",
  "Esa noche no durmió.",
  "Al amanecer, volvió a cubrir el pozo, clavó tablas, puso más piedras, y se marchó de la casa sin mirar atrás.",
  "No volvió jamás, pero cada tanto, soñaba que caminaba por corredores subterráneos, guiada por esa voz que conocía su nombre.",
  "La última vez que soñó, la voz le dijo que ya no necesitaba llamarla, que ella sola vendría.",
  "Cuando me lo contó, sus ojos no parpadeaban, como si aún oyera algo mientras hablaba.",
  "No le pregunté si era verdad, pero en mis viajes he visto pozos iguales, sin agua, sin fondo, demasiado quietos.",
  "Y siempre me alejo sin mirar dentro, porque uno nunca sabe quién está esperando al final de esa oscuridad."
]

# %%
prefijo="HuellasEnLaCeniza"

frases=[
  "Yo soy El Carretero, y esta historia se llama: Las huellas en la ceniza.",
  "La encontré yo mismo, mientras cruzaba una región donde todo olía a madera quemada.",
  "No había árboles, ni casas, ni voces, solo un paisaje cubierto por ceniza blanca como sal.",
  "Los restos de un pueblo estaban enterrados bajo ella, con estructuras caídas como esqueletos de carbón.",
  "La brisa era ligera, pero levantaba columnas de ceniza que parecían formas humanas danzando en silencio.",
  "Avancé con cuidado, y fue entonces cuando vi las huellas.",
  "No eran mías, ni de animal, eran de pies descalzos, pequeños, marcados con claridad en la capa de polvo.",
  "Iban en línea recta, una tras otra, sin desvíos, sin pausa.",
  "Las seguí, porque uno aprende que en lugares como ese no se deja rastro por casualidad.",
  "Las huellas llegaban hasta una puerta rota, que aún colgaba de una bisagra oxidada.",
  "Dentro solo había silencio y un aire denso como si algo acabara de exhalar profundamente.",
  "Las huellas seguían hasta el rincón de la habitación.",
  "Allí había un espejo intacto, el único objeto que no estaba cubierto de ceniza.",
  "Y justo en el cristal, una frase escrita con un dedo, como si hubiera sido trazada desde dentro.",
  "Decía: 'No los olvides.'",
  "Las huellas no regresaban, terminaban allí, justo frente al espejo.",
  "Esperé, como si algo más fuera a aparecer, pero no ocurrió nada.",
  "Cuando salí, ya no había viento, y las demás huellas que había dejado yo mismo habían desaparecido.",
  "Solo quedaban las originales, las del niño o niña, quien fuera, que aún esperaban frente al espejo.",
  "Yo no sé quién fue ni qué quiso mostrarme.",
  "Solo sé que hay lugares donde el olvido pesa más que la muerte, y alguien debe recordarlos, aunque sea en silencio."
]

# %%
ruta="./SpeechT5/habitacion/"

os.mkdir(ruta+"temp/")

i=1
archivos_a_unir = []
for text in frases:
    nombreOrig=ruta+"temp/"+prefijo+str(i)+"Orig.wav"
    nombreRev=ruta+"temp/"+prefijo+str(i)+"Rev.wav"
    nombre=prefijo+str(i)+".wav"
    archivos_a_unir.append(nombre)
    nombre=ruta+"temp/"+nombre
    if i > 1:
        tts.tts_to_file(text=text, file_path=nombreOrig)
        cmd = [
            'ffmpeg',
            '-i',
            nombreOrig,
            '-af',
            'areverse,atrim=start=1.0',
            '-c:a',      # Especifica el códec de audio (opcional, pero recomendado)
            'pcm_s16le', # Ejemplo de códec WAV (PCM signed 16-bit little-endian)
            nombreRev
        ]
        subprocess.run(cmd)
        # time.sleep(0.1)
        cmd = [
            'ffmpeg',
            '-i',
            nombreRev,
            '-af',
            'areverse',
            '-c:a',      # Especifica el códec de audio (opcional, pero recomendado)
            'pcm_s16le', # Ejemplo de códec WAV (PCM signed 16-bit little-endian)
            nombre
        ]
        subprocess.run(cmd)
        # time.sleep(0.1)
    else:
        tts.tts_to_file(text=text, file_path=nombre)
    i+=1

#Unir Archivos
with open('./SpeechT5/habitacion/temp/lista_wav.txt', 'w') as f:
    for archivo in archivos_a_unir:
        f.write(f"file '{archivo}'\n")

cmd = [
    'ffmpeg',
    '-f',
    'concat',
    '-safe',
    '0',
    '-i',
    './SpeechT5/habitacion/temp/lista_wav.txt',
    '-c',
    'copy',
    ruta+prefijo+".wav"
]
subprocess.run(cmd)

cmd = [
	'rm',
	'-r',
	ruta+"temp/"
]

subprocess.run(cmd)
# Out:
#  > Text splitted to sentences.
# ['Yo soy El Carretero, y esta historia se llama: Las huellas en la ceniza.']
#  > Processing time: 0.30522799491882324
#  > Real-time factor: 0.057645927161505184
#  > Text splitted to sentences.
# ['La encontré yo mismo, mientras cruzaba una región donde todo olía a madera quemada.']
#  > Processing time: 0.6193418502807617
#  > Real-time factor: 0.09733498545081248
# ffmpeg version 5.1.6-0+deb12u1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12 (Debian 12.2.0-14)
# ...

# %% [markdown]
# ### Removiendo silencios FORMA 2 - NO FUNCIONA

# %%
tts = TTS(model_name="tts_models/es/css10/vits")
frases=["Esta historia se llama: Habitación sin salida.",
"No recuerdo cómo llegué a este lugar.",
"Solo sé que, al abrir los ojos, estaba en una habitación blanca, sin ventanas, sin puertas.",
"No sentía hambre, ni frío.",
"Solo esa incomodidad de saber que algo estaba mal.",
"Caminaba de un lado a otro, buscando alguna grieta, alguna marca en las paredes lisas.",
"Nada.",
"El techo era tan alto que se perdía en una bruma pálida.",
"El suelo, blando como si pisara sobre algo que respiraba lentamente.",
# "Al principio pensé que era un sueño.",
# "Me pellizqué, grité, rasgué mis uñas contra las paredes.",
# "Todo era real.",
# "Pasaron horas o días.",
# "El tiempo no existía en ese lugar.",
# "Solo yo y mis pensamientos, repitiéndose como un eco interminable.",
# "A veces, en las paredes, aparecían breves destellos: imágenes que desaparecían si parpadeaba.",
# "Una calle conocida.",
# "Un rostro querido.",
# "Mi propia habitación, vacía.",
# "Intenté hablar, gritar, suplicar.",
# "Nadie respondía.",
# "Hasta que un día, en el centro de la habitación, apareció una puerta diminuta, apenas lo suficientemente grande para meter la mano.",
# "Me acerqué, desesperado.",
# "Escuché voces al otro lado.",
# "Voces que me llamaban por mi nombre.",
# "Metí la mano... y sentí dedos aferrándose a la mía.",
# "Pero no tiraban de mí para sacarme.",
# "Tiraban para arrastrarme más adentro.",
# "Intenté soltarme, pero era tarde.",
# "Fui absorbido por esa grieta diminuta, cayendo hacia un vacío de susurros y risas apagadas.",
# "Ahora no estoy seguro de dónde estoy.",
# "A veces veo lugares familiares, gente que parece no verme.",
# "A veces sueño con estar de nuevo en aquella habitación blanca.",
"O quizás... nunca salí de allí."]

ruta="./SpeechT5/habitacion/"
prefijo="HabitaciónSinSalida"

i=1
archivos_a_unir = []
for text in frases:
	nombreOrig=ruta+"temp/"+prefijo+str(i)+"Orig.wav"
	# nombreRev=ruta+"temp/"+prefijo+str(i)+"Rev.wav"
	nombre=prefijo+str(i)+".wav"
	archivos_a_unir.append(nombre)
	nombre=ruta+nombre
	tts.tts_to_file(text=text, file_path=nombreOrig)

	cmd = [
		'ffmpeg',
		'-i',
		nombreOrig,
		'-af',
		'silenceremove=start_periods=2:stop_periods=1:stop_duration=0:stop_threshold=-100dB',
		nombre
	]
	subprocess.run(cmd)
	i+=1

cmd = [
	'rm',
	'-r',
	ruta+"temp/"
]

subprocess.run(cmd)

#Unir Archivos
with open('./SpeechT5/habitacion/lista_wav.txt', 'w') as f:
    for archivo in archivos_a_unir:
        f.write(f"file '{archivo}'\n")

cmd = [
    'ffmpeg',
    '-f',
    'concat',
    '-safe',
    '0',
    '-i',
    './SpeechT5/habitacion/lista_wav.txt',
    '-c',
    'copy',
    ruta+prefijo+".wav"
]
subprocess.run(cmd)
# Out:
#  > tts_models/es/css10/vits is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > initialization of speaker-embedding layers.
#  > initialization of language-embedding layers.
# ...

# %%
print(ruta+prefijo+".wav")
# Out:
# ./SpeechT5/habitacion/HabitaciónSinSalida.wav

# %%
cmd = [
    'ffmpeg',
    '-f',
    'concat',
    '-safe',
    '0',
    '-i',
    './SpeechT5/habitacion/lista_wav.txt',
    '-c',
    'copy',
    ruta+prefijo+".wav"
]
subprocess.run(cmd)
# Out:
# ffmpeg version 5.1.6-0+deb12u1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 12 (Debian 12.2.0-14)
# ...

# %% [markdown]
# ## Español Latinoamericano

# %%
# Modelo multilingüe con soporte para español
tts = TTS("tts_models/multilingual/multi-dataset/your_tts")
# Out:
#  > tts_models/multilingual/multi-dataset/your_tts is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
# ...

# %%
print(tts.speakers)
# Out:
# ['female-en-5', 'female-en-5\n', 'female-pt-4\n', 'male-en-2', 'male-en-2\n', 'male-pt-3\n']

# %%
now = datetime.now()
formatted_time = now.strftime("%Y%m%d%H%M%S")
# Síntesis con texto en español latino
tts.tts_to_file(text="Hola, esta es una prueba con acento más neutro de Latinoamérica.", file_path="./SpeechT5/coquiAudiolatino"+formatted_time+".wav",language="en",speaker="female-en-5")
# Out:
#  > Text splitted to sentences.
# ['Hola, esta es una prueba con acento más neutro de Latinoamérica.']
#  > Processing time: 0.8577497005462646
#  > Real-time factor: 0.1553612933429206
# './SpeechT5/coquiAudiolatino20250430031451.wav'
