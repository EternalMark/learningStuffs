# %%
codigo="""
# reproductor.py
import pygame
import keyboard
import os
import time

# Configura la carpeta de audios
CARPETA = "./"
EXTENSIONES = (".mp3", ".wav", ".ogg")

# Inicializa el reproductor
pygame.mixer.init()
audios = [os.path.join(CARPETA, f) for f in os.listdir(CARPETA) if f.endswith(EXTENSIONES)]
playlist = []
index = 0

def reproducir(i):
    if 0 <= i < len(audios):
        pygame.mixer.music.load(audios[i])
        pygame.mixer.music.play()
        print(f"Reproduciendo: {os.path.basename(audios[i])}")

print("Controles:")
print(" [ESPACIO] reproducir/pausar | [n] siguiente | [a] agregar a playlist | [s] guardar playlist | [q] salir")

while True:
    if keyboard.is_pressed("space"):
        if pygame.mixer.music.get_busy():
            pygame.mixer.music.pause()
        else:
            pygame.mixer.music.unpause()
        keyboard.wait("space")

    elif keyboard.is_pressed("n"):
        index = (index + 1) % len(audios)
        reproducir(index)
        keyboard.wait("n")

    elif keyboard.is_pressed("a"):
        playlist.append(audios[index])
        print(f"Añadido: {os.path.basename(audios[index])}")
        keyboard.wait("a")

    elif keyboard.is_pressed("s"):
        with open("playlist.txt", "w") as f:
            for item in playlist:
                f.write(item + "\n")
        print("Playlist guardada.")
        keyboard.wait("s")

    elif keyboard.is_pressed("q"):
        print("Saliendo.")
        break

    time.sleep(0.1)
"""

# %%
from datetime import datetime
now = datetime.now()
formatted_time = now.strftime("%Y%m%d%H%M%S")
nameofpy="reproductor"+formatted_time+".py"

with open(nameofpy, "w") as f:
    f.write(codigo)

# %%
# !pyinstaller --onefile {nameofpy}
# Out:
# 176 INFO: PyInstaller: 6.13.0, contrib hooks: 2025.4
# 176 INFO: Python: 3.11.11
# 177 INFO: Platform: Linux-6.11.0-25-generic-x86_64-with-glibc2.36
# 177 INFO: Python environment: /usr/local
# 178 INFO: wrote /home/jupyter/reproductor20250520035421.spec
# 179 INFO: Module search paths (PYTHONPATH):
# ['/usr/local/lib/python311.zip',
#  '/usr/local/lib/python3.11',
#  '/usr/local/lib/python3.11/lib-dynload',
#  '/usr/local/lib/python3.11/site-packages',
#  '/home/jupyter']
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 737 INFO: checking Analysis
# 738 INFO: Building Analysis because Analysis-00.toc is non existent
# 738 INFO: Running Analysis Analysis-00.toc
# 738 INFO: Target bytecode optimization level: 0
# 738 INFO: Initializing module dependency graph...
# 738 INFO: Initializing module graph hook caches...
# 745 INFO: Analyzing modules for base_library.zip ...
# 1514 INFO: Processing standard module hook 'hook-heapq.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 1565 INFO: Processing standard module hook 'hook-encodings.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 2777 INFO: Processing standard module hook 'hook-pickle.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 3763 INFO: Caching module dependency graph...
# 3792 INFO: Looking for Python shared library...
# 3797 INFO: Using Python shared library: /usr/local/lib/libpython3.11.so.1.0
# 3797 INFO: Analyzing /home/jupyter/reproductor20250520035421.py
#
# Syntax error in /home/jupyter/reproductor20250520035421.py
#   File "/home/jupyter/reproductor20250520035421.py", line 48
#      f.write(item + "
#                     ^
#  SyntaxError: unterminated string literal (detected at line 48)

# %%
# !pyinstaller --onefile reproductor.py
# Out:
# 162 INFO: PyInstaller: 6.13.0, contrib hooks: 2025.4
# 162 INFO: Python: 3.11.11
# 163 INFO: Platform: Linux-6.11.0-25-generic-x86_64-with-glibc2.36
# 163 INFO: Python environment: /usr/local
# 164 INFO: wrote /home/jupyter/reproductor.spec
# 165 INFO: Module search paths (PYTHONPATH):
# ['/usr/local/lib/python311.zip',
#  '/usr/local/lib/python3.11',
#  '/usr/local/lib/python3.11/lib-dynload',
#  '/usr/local/lib/python3.11/site-packages',
#  '/home/jupyter']
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 775 INFO: checking Analysis
# 781 INFO: Building because /home/jupyter/reproductor.py changed
# 781 INFO: Running Analysis Analysis-00.toc
# 781 INFO: Target bytecode optimization level: 0
# 781 INFO: Initializing module dependency graph...
# 782 INFO: Initializing module graph hook caches...
# 787 INFO: Analyzing modules for base_library.zip ...
# 1693 INFO: Processing standard module hook 'hook-heapq.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 1762 INFO: Processing standard module hook 'hook-encodings.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 2979 INFO: Processing standard module hook 'hook-pickle.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 3998 INFO: Caching module dependency graph...
# 4027 INFO: Looking for Python shared library...
# 4033 INFO: Using Python shared library: /usr/local/lib/libpython3.11.so.1.0
# 4033 INFO: Analyzing /home/jupyter/reproductor.py
# 4041 INFO: Processing standard module hook 'hook-pygame.py' from '/usr/local/lib/python3.11/site-packages/pygame/__pyinstaller'
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 4165 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 4165 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 4573 INFO: Processing standard module hook 'hook-numpy.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 4948 INFO: Processing standard module hook 'hook-difflib.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 5062 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 5218 INFO: Processing standard module hook 'hook-xml.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 5670 INFO: Processing standard module hook 'hook-platform.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 5684 INFO: Processing standard module hook 'hook-sysconfig.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 6076 INFO: Processing standard module hook 'hook-psutil.py' from '/usr/local/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 7254 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 8048 INFO: Processing module hooks (post-graph stage)...
# 8093 INFO: Processing pre-safe-import-module hook 'hook-win32com.py' from '/usr/local/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/pre_safe_import_module'
# 8608 INFO: Processing standard module hook 'hook-jinja2.py' from '/usr/local/lib/python3.11/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 8975 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 8978 INFO: Processing standard module hook 'hook-packaging.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks'
# 9090 INFO: Performing binary vs. data reclassification (3 entries)
# 9093 INFO: Looking for ctypes DLLs
# 9200 INFO: Analyzing run-time hooks ...
# 9202 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 9204 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 9205 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 9206 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/usr/local/lib/python3.11/site-packages/PyInstaller/hooks/rthooks'
# 9214 INFO: Creating base_library.zip...
# 9265 INFO: Looking for dynamic libraries
# 10112 INFO: Warnings written to /home/jupyter/build/reproductor/warn-reproductor.txt
# 10148 INFO: Graph cross-reference written to /home/jupyter/build/reproductor/xref-reproductor.html
# 10162 INFO: checking PYZ
# 10176 INFO: checking PKG
# 10178 INFO: Building because toc changed
# 10178 INFO: Building PKG (CArchive) reproductor.pkg
# 19320 INFO: Building PKG (CArchive) reproductor.pkg completed successfully.
# 19323 INFO: Bootloader /usr/local/lib/python3.11/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 19323 INFO: checking EXE
# 19324 INFO: Building because toc changed
# 19324 INFO: Building EXE from EXE-00.toc
# 19328 INFO: Copying bootloader EXE to /home/jupyter/dist/reproductor
# 19328 INFO: Appending PKG archive to custom ELF section in EXE
# 19959 INFO: Building EXE from EXE-00.toc completed successfully.
# 19962 INFO: Build complete! The results are available in: /home/jupyter/dist
