# %%
# !pip install git+https://github.com/jpgallegoar/Spanish-F5.git
# Out:
# ...
#   Cloning https://github.com/jpgallegoar/Spanish-F5.git to /tmp/pip-req-build-9of55tar
#   Running command git clone --filter=blob:none --quiet https://github.com/jpgallegoar/Spanish-F5.git /tmp/pip-req-build-9of55tar
#   Resolved https://github.com/jpgallegoar/Spanish-F5.git to commit 289b89d72336a9ad5617f77003567ab23d90a5f1
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/122.4 MB 22.4 kB/s eta 1:29:47^C
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/122.4 MB 22.4 kB/s eta 1:29:47

# %%
# !f5-tts_infer-gradio
# Out:
# 2024-11-05 11:51:09.358414: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-05 11:51:09.377500: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-05 11:51:09.383291: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-05 11:51:09.397210: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
