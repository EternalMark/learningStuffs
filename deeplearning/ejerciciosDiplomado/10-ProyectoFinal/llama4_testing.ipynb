# %%
from transformers import AutoProcessor, Llama4ForConditionalGeneration
import torch
# Out:
# 2025-04-21 03:11:42.990307: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745205103.003788       9 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745205103.007873       9 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-21 03:11:43.021812: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# pip install accelerate
#
# huggingface-cli login
# //Insertar el token, decir no a lo de git

# %%
model_id = "meta-llama/Llama-4-Scout-17B-16E-Instruct"

processor = AutoProcessor.from_pretrained(model_id)
model = Llama4ForConditionalGeneration.from_pretrained(
    model_id,
    attn_implementation="flex_attention",
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

#First time download 41min
# Out:
# Loading checkpoint shards:   0%|          | 0/50 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the disk and cpu.

# %%
url1 = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/0052a70beed5bf71b92610a43a52df6d286cd5f3/diffusers/rabbit.jpg"
url2 = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/datasets/cat_style_layout.png"
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image", "url": url1},
            {"type": "image", "url": url2},
            {"type": "text", "text": "Can you describe how these two images are similar, and how they differ?"},
        ]
    },
]

# %%
messages = [
    {
        "role": "user",
        "content": [
            # {"type": "image", "url": url1},
            # {"type": "image", "url": url2},
            {"type": "text", "text": "Hola como estas?"},
        ]
    },
]

# %%
inputs = processor.apply_chat_template(
    messages,
    add_generation_prompt=True,
    tokenize=True,
    return_dict=True,
    return_tensors="pt",
).to(model.device)

outputs = model.generate(
    **inputs,
    max_new_tokens=256,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       1 inputs = processor.apply_chat_template(
#       2     messages,
#       3     add_generation_prompt=True,
#    (...)
#       6     return_tensors="pt",
#       7 ).to(model.device)
# ----> 9 outputs = model.generate(
#      10     **inputs,
#      11     max_new_tokens=256,
#      12 )
#
# File /usr/local/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/transformers/generation/utils.py:2465, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2457     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2458         input_ids=input_ids,
#    2459         expand_size=generation_config.num_return_sequences,
#    2460         is_encoder_decoder=self.config.is_encoder_decoder,
#    2461         **model_kwargs,
#    2462     )
#    2464     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2465     result = self._sample(
#    2466         input_ids,
#    2467         logits_processor=prepared_logits_processor,
#    2468         stopping_criteria=prepared_stopping_criteria,
#    2469         generation_config=generation_config,
#    2470         synced_gpus=synced_gpus,
#    2471         streamer=streamer,
#    2472         **model_kwargs,
#    2473     )
#    2475 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2476     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2477     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2478         input_ids=input_ids,
#    2479         expand_size=generation_config.num_beams,
#    2480         is_encoder_decoder=self.config.is_encoder_decoder,
#    2481         **model_kwargs,
#    2482     )
#
# File /usr/local/lib/python3.11/site-packages/transformers/generation/utils.py:3434, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3432     is_prefill = False
#    3433 else:
# -> 3434     outputs = model_forward(**model_inputs, return_dict=True)
#    3436 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3437 model_kwargs = self._update_model_kwargs_for_generation(
#    3438     outputs,
#    3439     model_kwargs,
#    3440     is_encoder_decoder=self.config.is_encoder_decoder,
#    3441 )
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/site-packages/accelerate/hooks.py:176, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     174         output = module._old_forward(*args, **kwargs)
#     175 else:
# --> 176     output = module._old_forward(*args, **kwargs)
#     177 return module._hf_hook.post_forward(module, output)
#
# File /usr/local/lib/python3.11/site-packages/transformers/models/llama4/modeling_llama4.py:1776, in Llama4ForConditionalGeneration.forward(self, input_ids, pixel_values, attention_mask, position_ids, past_key_values, inputs_embeds, vision_feature_layer, vision_feature_select_strategy, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, logits_to_keep, image_sizes, **lm_kwargs)
#    1773     inputs_embeds = inputs_embeds.masked_scatter(expanded_mask, projected_vision_flat)
#    1774     inputs_embeds = inputs_embeds.view(original_inputs_embeds_shape)
# -> 1776 outputs = self.language_model(
#    1777     attention_mask=attention_mask,
#    1778     position_ids=position_ids,
#    1779     past_key_values=past_key_values,
#    1780     inputs_embeds=inputs_embeds,
#    1781     use_cache=use_cache,
#    1782     output_attentions=output_attentions,
#    1783     output_hidden_states=output_hidden_states,
#    1784     return_dict=return_dict,
#    1785     cache_position=cache_position,
#    1786     logits_to_keep=logits_to_keep,
#    1787     **lm_kwargs,
#    1788 )
#    1790 logits = outputs[0]
#    1792 loss = None
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/site-packages/transformers/models/llama4/modeling_llama4.py:1030, in Llama4ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, logits_to_keep, **kwargs)
#    1027 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1029 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1030 outputs = self.model(
#    1031     input_ids=input_ids,
#    1032     attention_mask=attention_mask,
#    1033     position_ids=position_ids,
#    1034     past_key_values=past_key_values,
#    1035     inputs_embeds=inputs_embeds,
#    1036     use_cache=use_cache,
#    1037     output_attentions=output_attentions,
#    1038     output_hidden_states=output_hidden_states,
#    1039     return_dict=return_dict,
#    1040     cache_position=cache_position,
#    1041     **kwargs,
#    1042 )
#    1044 hidden_states = outputs[0]
#    1045 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/site-packages/transformers/models/llama4/modeling_llama4.py:701, in Llama4TextModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     687     layer_outputs = self._gradient_checkpointing_func(
#     688         decoder_layer.__call__,
#     689         hidden_states,
#    (...)
#     698         freq_cis,
#     699     )
#     700 else:
# --> 701     layer_outputs = decoder_layer(
#     702         hidden_states,
#     703         attention_mask=causal_mask,
#     704         chunk_causal_mask=chunk_causal_mask,
#     705         position_ids=position_ids,
#     706         past_key_value=past_key_values,
#     707         output_attentions=output_attentions,
#     708         use_cache=use_cache,
#     709         cache_position=cache_position,
#     710         position_embeddings=freq_cis,
#     711         **flash_attn_kwargs,
#     712     )
#     714 hidden_states = layer_outputs[0]
#     716 if output_attentions:
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/site-packages/accelerate/hooks.py:176, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     174         output = module._old_forward(*args, **kwargs)
#     175 else:
# --> 176     output = module._old_forward(*args, **kwargs)
#     177 return module._hf_hook.post_forward(module, output)
#
# File /usr/local/lib/python3.11/site-packages/transformers/models/llama4/modeling_llama4.py:451, in Llama4TextDecoderLayer.forward(self, hidden_states, attention_mask, chunk_causal_mask, position_ids, past_key_value, output_attentions, output_router_logits, use_cache, cache_position, position_embeddings, **kwargs)
#     448 residual = hidden_states
#     450 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 451 hidden_states = self.feed_forward(hidden_states)
#     452 if self.is_moe_layer:
#     453     hidden_states, router_logits = hidden_states
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/site-packages/accelerate/hooks.py:176, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     174         output = module._old_forward(*args, **kwargs)
#     175 else:
# --> 176     output = module._old_forward(*args, **kwargs)
#     177 return module._hf_hook.post_forward(module, output)
#
# File /usr/local/lib/python3.11/site-packages/transformers/models/llama4/modeling_llama4.py:184, in Llama4TextMoe.forward(self, hidden_states)
#     182 # we gather inputs corresponding to each expert based on the router indices
#     183 routed_in = routed_in * router_scores.reshape(-1, 1)
# --> 184 routed_out = self.experts(routed_in)
#     185 out = self.shared_expert(hidden_states)
#     186 # now that we finished expert computation -> we scatter add because we gathered previously
#     187 # we have to do this because we used all experts on all tokens. This is faster than the for loop, tho you are compute bound
#     188 # this scales a lot better if you do EP!
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /usr/local/lib/python3.11/site-packages/accelerate/hooks.py:171, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     170 def new_forward(module, *args, **kwargs):
# --> 171     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     172     if module._hf_hook.no_grad:
#     173         with torch.no_grad():
#
# File /usr/local/lib/python3.11/site-packages/accelerate/hooks.py:342, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     335 for name, _ in named_module_tensors(
#     336     module,
#     337     include_buffers=self.offload_buffers,
#     338     recurse=self.place_submodules,
#     339     remove_non_persistent=True,
#     340 ):
#     341     fp16_statistics = None
# --> 342     value = self.weights_map[name]
#     343     if "weight" in name and name.replace("weight", "SCB") in self.weights_map.keys():
#     344         if value.dtype == torch.int8:
#
# File /usr/local/lib/python3.11/site-packages/accelerate/utils/offload.py:118, in PrefixedDataset.__getitem__(self, key)
#     117 def __getitem__(self, key):
# --> 118     return self.dataset[f"{self.prefix}{key}"]
#
# File /usr/local/lib/python3.11/site-packages/accelerate/utils/offload.py:170, in OffloadedWeightsLoader.__getitem__(self, key)
#     168 tensor = None
#     169 try:
# --> 170     with safe_open(weight_info["safetensors_file"], framework="pt", device=device) as f:
#     171         tensor = f.get_tensor(weight_info.get("weight_name", key))
#     172 except TypeError:
#     173     # if failed to get_tensor on the device, such as bf16 on mps, try to load it on CPU first
#
# KeyboardInterrupt:

# %%
response = processor.batch_decode(outputs[:, inputs["input_ids"].shape[-1]:])[0]
print(response)
print(outputs[0])
